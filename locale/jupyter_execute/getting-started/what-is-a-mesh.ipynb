# %%
import pyvista as pv
pv.set_jupyter_backend('panel')
pv.set_plot_theme('document')

# %%
import numpy as np
import pyvista as pv

nodes = np.random.rand(100, 3)
mesh = pv.PolyData(nodes)
mesh.plot(point_size=10)
# Out:
# <div id='1003'>
#
#
#
#
#
#   <div class="bk-root" id="f2f4df87-c229-4d6e-8923-df6f95566c88" data-root-id="1003"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"5cf6ed45-f5d4-41c3-8b9b-9835e8972d74":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"231d3c90dedca3cd197c58d757f82833":"...","2ebda7d3c6c3627ba233a85b7027cd58":"...","e361de470385ca350ab5283b6e899ab5":"..."},"axes":{"id":"1002"},"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e09476c3b0}"]],["addRenderer",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e09477b630}"]],["addRenderer",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e09476b340}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055e0948bf930}"]],["addViewProp",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b59510}"]]],"dependencies":[{"id":"000055e0948bf930","parent":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e09476c3b0","properties":{"clippingRange":[1.5527287455810133,5.436853491193878],"focalPoint":[0.503467330556087,0.5116715651027399,0.504531802937885],"position":[2.390707031209271,2.398911265755924,2.391771503591069],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b56830}"]],["setProperty",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e0932df4b0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b56830-dataset-0}",0]],["setLookupTable",["instance:${72b5a220-77a5-4411-8859-4a6eafe704c0000055e0944f2d50}"]]],"dependencies":[{"id":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b56830-dataset-0","parent":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b56830","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"231d3c90dedca3cd197c58d757f82833","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.9996208201053779,"min":0.007313841006795996},{"component":null,"max":0.989408778618599,"min":0.03393435158688096},{"component":null,"max":0.9958153879234655,"min":0.013248217952304575},{"component":null,"max":1.6102850714513055,"min":0.27961469922628845}],"size":300,"vtkClass":"vtkPoints"},"verts":{"dataType":"Uint32Array","hash":"e361de470385ca350ab5283b6e899ab5","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":99.0,"min":0.0}],"size":200,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e0944f2d50","parent":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b56830","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b56830","parent":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b59510","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e0932df4b0","parent":"72b5a220-77a5-4411-8859-4a6eafe704c0000055e094b59510","properties":{"ambient":0.0,"ambientColor":[0.8235294117647058,0.7058823529411765,0.5490196078431373],"backfaceCulling" ...
#     var render_

# %%
from pyvista import examples

mesh = examples.load_hexbeam()
bcpos = [(6.20, 3.00, 7.50),
         (0.16, 0.13, 2.65),
         (-0.28, 0.94, -0.21)]

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
       point_size=10, render_points_as_spheres=True)
pl.camera_position = bcpos
pl.show()
# Out:
# <div id='1007'>
#
#
#
#
#
#   <div class="bk-root" id="ff75af23-0154-47b9-a775-95a80c831e3d" data-root-id="1007"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e56e1680-70e0-4551-8f64-fa6ab176bcec":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"client_comm_id":"11a0df6d35f448399471d04870b9596b","comm_id":"92c15a5e24054bbeb1ff1ff1de25f7b9","plot_id":"1007"},"id":"1008","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1006","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"..."},"axes":{"id":"1006"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095618db0}"]],["addRenderer",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e0956183f0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055e094added0}"]],["addViewProp",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095440770}"]],["addViewProp",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a84420}"]]],"dependencies":[{"id":"000055e094added0","parent":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095618db0","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a7b2a0}"]],["setProperty",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a6d9c0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a7b2a0-dataset-0}",0]],["setLookupTable",["instance:${ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095ab75f0}"]]],"dependencies":[{"id":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a7b2a0-dataset-0","parent":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a7b2a0","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095ab75f0","parent":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a7b2a0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a7b2a0","parent":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095440770","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e095a6d9c0","parent":"ea269b82-139a-477d-bf33-5ff09a5b1f6c000055e0954407 ...

# %%
mesh = examples.download_bunny_coarse()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)
pl.camera_position = [(0.02, 0.30, 0.73),
                      (0.02, 0.03, -0.022),
                      (-0.03, 0.94, -0.34)]
pl.show()
# Out:
# <div id='1010'>
#
#
#
#
#
#   <div class="bk-root" id="0db49006-64e4-4b83-9dae-4bb92aec0e68" data-root-id="1010"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"02ecc6e9-3887-4fbc-baaa-3dafcdc0c168":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"client_comm_id":"d705de142b3d444c93d935b9f2fdf393","comm_id":"5c549182b97a419eb6f1f8ec547c511d","plot_id":"1010"},"id":"1011","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1009","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"09274232a877f0c3c872ae7ea3573599":"...","233c95f9c627ae8343c4314291d001d7":"...","2ebda7d3c6c3627ba233a85b7027cd58":"...","364c82e904258502159946249464beb2":"...","bbd1e662f41e7ea2534dbeb97e952dff":"...","f126fd8aa224af8062956f0c00bc2c0c":"..."},"axes":{"id":"1009"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e095a124a0}"]],["addRenderer",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e0960939a0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055e09612d1d0}"]],["addViewProp",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e0960f0220}"]],["addViewProp",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e095fae550}"]]],"dependencies":[{"id":"000055e09612d1d0","parent":"0f50e363-f910-4ae5-aff7-aa5857b72a15000055e095a124a0","properties":{"clippingRange":[0.46024900135143143,1.2251304034277937],"focalPoint":[0.02,0.03,-0.022],"position":[0.02,0.3,0.73],"viewUp":[-0.02999850011249063,0.9399530035247063,-0.33998300127489384]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e096130760}"]],["setProperty",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e095a42c90}"]]],"dependencies":[{"calls":[["setInputData",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e096130760-dataset-0}",0]],["setLookupTable",["instance:${0f50e363-f910-4ae5-aff7-aa5857b72a15000055e0961332f0}"]]],"dependencies":[{"id":"0f50e363-f910-4ae5-aff7-aa5857b72a15000055e096130760-dataset-0","parent":"0f50e363-f910-4ae5-aff7-aa5857b72a15000055e096130760","properties":{"fields":[{"dataType":"Float32Array","hash":"f126fd8aa224af8062956f0c00bc2c0c","location":"pointData","name":"Normals","numberOfComponents":3,"ranges":[{"component":null,"max":0.9976677298545837,"min":-0.9997695088386536},{"component":null,"max":0.9959895014762878,"min":-0.9998428821563721},{"component":null,"max":0.9974686503410339,"min":-0.998054563999176},{"component":null,"max":1.0000000408603298,"min":0.9999999604990634}],"registration":"setNormals","size":2616,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float32Array","hash":"364c82e904258502159946249464beb2","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.18016336858272552,"min":-0.13155962526798248},{"component":null,"max":0.18769524991512299,"min":-0.12048563361167908},{"component":null,"max":0.09850578755140305,"min":-0.14300920069217682},{"component":null,"max":0.23461699358757118,"min":0.0639391221071615}],"size":2616,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"233c95f9c627ae8343c4314291d001d7","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":871.0,"min":0.0}],"size":4000,"vtkClass":"vtkCellArray"},"verts":{"dataType":"Uint32Array","hash":"bbd1e662f41e7ea2534dbeb97e952dff","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":501.0,"min":0.0}],"size":1004,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"0f50e363-f910-4ae5-aff7-aa5857b72a15000055e0961332f0","parent":"0f50e363-f910-4ae5-aff7-aa5857b72a15000055e096130760","prope ...

# %%
mesh = examples.load_hexbeam()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)

pl.add_mesh(mesh.extract_cells(mesh.n_cells-1),
            color='pink', edge_color='blue',
            line_width=5, show_edges=True)

pl.camera_position = [(6.20, 3.00, 7.50),
                      (0.16, 0.13, 2.65),
                      (-0.28, 0.94, -0.21)]
pl.show()
# Out:
# <div id='1013'>
#
#
#
#
#
#   <div class="bk-root" id="973eb9f8-4867-4b6d-a5d6-43288a7e0e84" data-root-id="1013"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c5ee8e08-5763-4ea4-a880-e2751a7b7455":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"...","8a8291eb26fea509eef318c50eb0fdad":"","a990b5ac895ff54373e8552a7fadab2e":""},"axes":{"id":"1012"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096032170}"]],["addRenderer",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e0966638e0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055e0967e2bc0}"]],["addViewProp",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096668380}"]],["addViewProp",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e0966a4190}"]],["addViewProp",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e09660b3a0}"]]],"dependencies":[{"id":"000055e0967e2bc0","parent":"4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096032170","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096754ea0}"]],["setProperty",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e0966db780}"]]],"dependencies":[{"calls":[["setInputData",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096754ea0-dataset-0}",0]],["setLookupTable",["instance:${4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e0967ecd80}"]]],"dependencies":[{"id":"4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096754ea0-dataset-0","parent":"4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096754ea0","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e0967ecd80","parent":"4d4e5ac5-b07c-4127-8c08-ccb95c4555e8000055e096754ea0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"4d4e5ac5-b07c-4127-8c08-ccb95c455 ...

# %%
mesh.point_arrays['my point values'] = np.arange(mesh.n_points)

mesh.plot(scalars='my point values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1017'>
#
#
#
#
#
#   <div class="bk-root" id="2466f0cf-52dd-48cb-995a-dc96fcc59c72" data-root-id="1017"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c9168fae-eda1-4e39-9170-6a74df83aabd":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ce52d598102e2756143cf4f27a0b5911":"...","e2ddbba971096529c0fc99f7c8331f6b":"..."},"axes":{"id":"1016"},"color_mappers":[{"id":"1015"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f57740}"]],["addRenderer",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e0954d26c0}"]],["addRenderer",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e095f7e890}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055e0966a87c0}"]],["addViewProp",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096ec6900}"]]],"dependencies":[{"id":"000055e0966a87c0","parent":"7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f57740","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f2bce0}"]],["setProperty",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096ec7280}"]]],"dependencies":[{"calls":[["setInputData",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f2bce0-dataset-0}",0]],["setLookupTable",["instance:${7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096e49290}"]]],"dependencies":[{"id":"7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f2bce0-dataset-0","parent":"7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f2bce0","properties":{"fields":[{"dataType":"Int32Array","hash":"e2ddbba971096529c0fc99f7c8331f6b","location":"pointData","name":"my point values","numberOfComponents":1,"ranges":[{"component":null,"max":98.0,"min":0.0}],"registration":"setScalars","size":99,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096e49290","parent":"7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f2bce0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[0.0,98.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,98.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096f2bce0","parent":"7fb545e1-456c-4292-9def-d3f59b9eaf30000055e096ec6900","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":1,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":1,"scalarRange":[0.0,98.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"7fb545e ...

# %%
mesh.cell_arrays['my cell values'] = np.arange(mesh.n_cells)
mesh.plot(scalars='my cell values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1021'>
#
#
#
#
#
#   <div class="bk-root" id="702d0be8-f78a-4e1d-b3a7-e860dde02bf5" data-root-id="1021"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"10fd9667-06c8-4e3d-943a-cfb37dbdbe90":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"high":39.0,"low":0.0,"name":"my cell values","palette":["#440154","#440255","#440357","#450558","#45065a","#45085b","#46095c","#460b5e","#460c5f","#460e61","#470f62","#471163","#471265","#471466","#471567","#471669","#47186a","#48196b","#481a6c","#481c6e","#481d6f","#481e70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472a79","#472b7a","#472c7b","#462d7c","#462f7c","#46307d","#46317e","#45327f","#45347f","#453580","#453681","#443781","#443982","#433a83","#433b83","#433c84","#423d84","#423e85","#424085","#414186","#414286","#404387","#404487","#3f4587","#3f4788","#3e4888","#3e4989","#3d4a89","#3d4b89","#3d4c89","#3c4d8a","#3c4e8a","#3b508a","#3b518a","#3a528b","#3a538b","#39548b","#39558b","#38568b","#38578c","#37588c","#37598c","#365a8c","#365b8c","#355c8c","#355d8c","#345e8d","#345f8d","#33608d","#33618d","#32628d","#32638d","#31648d","#31658d","#31668d","#30678d","#30688d","#2f698d","#2f6a8d","#2e6b8e","#2e6c8e","#2e6d8e","#2d6e8e","#2d6f8e","#2c708e","#2c718e","#2c728e","#2b738e","#2b748e","#2a758e","#2a768e","#2a778e","#29788e","#29798e","#287a8e","#287a8e","#287b8e","#277c8e","#277d8e","#277e8e","#267f8e","#26808e","#26818e","#25828e","#25838d","#24848d","#24858d","#24868d","#23878d","#23888d","#23898d","#22898d","#228a8d","#228b8d","#218c8d","#218d8c","#218e8c","#208f8c","#20908c","#20918c","#1f928c","#1f938b","#1f948b","#1f958b","#1f968b","#1e978a","#1e988a","#1e998a","#1e998a","#1e9a89","#1e9b89","#1e9c89","#1e9d88","#1e9e88","#1e9f88","#1ea087","#1fa187","#1fa286","#1fa386","#20a485","#20a585","#21a685","#21a784","#22a784","#23a883","#23a982","#24aa82","#25ab81","#26ac81","#27ad80","#28ae7f","#29af7f","#2ab07e","#2bb17d","#2cb17d","#2eb27c","#2fb37b","#30b47a","#32b57a","#33b679","#35b778","#36b877","#38b976","#39b976","#3bba75","#3dbb74","#3ebc73","#40bd72","#42be71","#44be70","#45bf6f","#47c06e","#49c16d","#4bc26c","#4dc26b","#4fc369","#51c468","#53c567","#55c666","#57c665","#59c764","#5bc862","#5ec961","#60c960","#62ca5f","#64cb5d","#67cc5c","#69cc5b","#6bcd59","#6dce58","#70ce56","#72cf55","#74d054","#77d052","#79d151","#7cd24f","#7ed24e","#81d34c","#83d34b","#86d449","#88d547","#8bd546","#8dd644","#90d643","#92d741","#95d73f","#97d83e","#9ad83c","#9dd93a","#9fd938","#a2da37","#a5da35","#a7db33","#aadb32","#addc30","#afdc2e","#b2dd2c","#b5dd2b","#b7dd29","#bade27","#bdde26","#bfdf24","#c2df22","#c5df21","#c7e01f","#cae01e","#cde01d","#cfe11c","#d2e11b","#d4e11a","#d7e219","#dae218","#dce218","#dfe318","#e1e318","#e4e318","#e7e419","#e9e419","#ece41a","#eee51b","#f1e51c","#f3e51e","#f6e61f","#f8e621","#fae622","#fde724"]},"id":"1019","type":"LinearColorMapper"},{"attributes":{"client_comm_id":"9db83a206f134f2e942c574f78ef5f60","comm_id":"b58357dfb56743bb9a2193448dee4717","plot_id":"1021"},"id":"1022","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ac3fb6801e30e41f7b521cd44e0bea96":"","ce52d598102e2756143cf4f27a0b5911":"..."},"axes":{"id":"1020"},"color_mappers":[{"id":"1019"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${edc2df09-1aef-4419-ad95-b656fba797b4000055e0974f13e0}"]],["addRenderer",["instance:${edc2df09-1aef-4419-ad95-b656fba797b4000055e097dbed60}"]],["addRenderer",["instance:${edc2df09-1aef-4419-ad95-b656fba797b4000055e097428420}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055e097e5a2e0} ...

# %%
mesh = examples.load_uniform()

pl = pv.Plotter(shape=(1,2))
pl.add_mesh(mesh, scalars='Spatial Point Data', show_edges=True)
pl.subplot(0,1)
pl.add_mesh(mesh, scalars='Spatial Cell Data', show_edges=True)
pl.show()
# Out:
# <div id='1025'>
#
#
#
#
#
#   <div class="bk-root" id="837ead46-c968-4927-a01c-58102ec1c7ef" data-root-id="1025"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"75332fc3-94ff-43f5-aa92-c1d11a64bf79":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"client_comm_id":"2c0d44d4601340cfb088300d5e1a5f5b","comm_id":"0e0c46b00b914497b7228654a68f5ec5","plot_id":"1025"},"id":"1026","type":"panel.models.comm_manager.CommManager"},{"attributes":{"high":729.0,"low":0.0,"name":"Spatial Point Data","palette":["#440154","#440255","#440357","#450558","#45065a","#45085b","#46095c","#460b5e","#460c5f","#460e61","#470f62","#471163","#471265","#471466","#471567","#471669","#47186a","#48196b","#481a6c","#481c6e","#481d6f","#481e70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472a79","#472b7a","#472c7b","#462d7c","#462f7c","#46307d","#46317e","#45327f","#45347f","#453580","#453681","#443781","#443982","#433a83","#433b83","#433c84","#423d84","#423e85","#424085","#414186","#414286","#404387","#404487","#3f4587","#3f4788","#3e4888","#3e4989","#3d4a89","#3d4b89","#3d4c89","#3c4d8a","#3c4e8a","#3b508a","#3b518a","#3a528b","#3a538b","#39548b","#39558b","#38568b","#38578c","#37588c","#37598c","#365a8c","#365b8c","#355c8c","#355d8c","#345e8d","#345f8d","#33608d","#33618d","#32628d","#32638d","#31648d","#31658d","#31668d","#30678d","#30688d","#2f698d","#2f6a8d","#2e6b8e","#2e6c8e","#2e6d8e","#2d6e8e","#2d6f8e","#2c708e","#2c718e","#2c728e","#2b738e","#2b748e","#2a758e","#2a768e","#2a778e","#29788e","#29798e","#287a8e","#287a8e","#287b8e","#277c8e","#277d8e","#277e8e","#267f8e","#26808e","#26818e","#25828e","#25838d","#24848d","#24858d","#24868d","#23878d","#23888d","#23898d","#22898d","#228a8d","#228b8d","#218c8d","#218d8c","#218e8c","#208f8c","#20908c","#20918c","#1f928c","#1f938b","#1f948b","#1f958b","#1f968b","#1e978a","#1e988a","#1e998a","#1e998a","#1e9a89","#1e9b89","#1e9c89","#1e9d88","#1e9e88","#1e9f88","#1ea087","#1fa187","#1fa286","#1fa386","#20a485","#20a585","#21a685","#21a784","#22a784","#23a883","#23a982","#24aa82","#25ab81","#26ac81","#27ad80","#28ae7f","#29af7f","#2ab07e","#2bb17d","#2cb17d","#2eb27c","#2fb37b","#30b47a","#32b57a","#33b679","#35b778","#36b877","#38b976","#39b976","#3bba75","#3dbb74","#3ebc73","#40bd72","#42be71","#44be70","#45bf6f","#47c06e","#49c16d","#4bc26c","#4dc26b","#4fc369","#51c468","#53c567","#55c666","#57c665","#59c764","#5bc862","#5ec961","#60c960","#62ca5f","#64cb5d","#67cc5c","#69cc5b","#6bcd59","#6dce58","#70ce56","#72cf55","#74d054","#77d052","#79d151","#7cd24f","#7ed24e","#81d34c","#83d34b","#86d449","#88d547","#8bd546","#8dd644","#90d643","#92d741","#95d73f","#97d83e","#9ad83c","#9dd93a","#9fd938","#a2da37","#a5da35","#a7db33","#aadb32","#addc30","#afdc2e","#b2dd2c","#b5dd2b","#b7dd29","#bade27","#bdde26","#bfdf24","#c2df22","#c5df21","#c7e01f","#cae01e","#cde01d","#cfe11c","#d2e11b","#d4e11a","#d7e219","#dae218","#dce218","#dfe318","#e1e318","#e4e318","#e7e419","#e9e419","#ece41a","#eee51b","#f1e51c","#f3e51e","#f6e61f","#f8e621","#fae622","#fde724"]},"id":"1023","type":"LinearColorMapper"},{"attributes":{"arrays":{"82e430eab61792abaf6b93b3e7efbd26":"...","ce52d598102e2756143cf4f27a0b5911":"...","e29e0c63339d8d1d879b645e2c536af4":"...","ef0b202855df439aff207db187b28d7f":"...","f26b7ce42162ae450c6c0266500ad97e":"..."},"axes":{"id":"1024"},"color_mappers":[{"id":"1023"}],"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${767e2df7-072c-4082-a002-4f64691e7461000055e0985ed060}"]],["addRenderer",["instance:${767e2df7-072c-4082-a002-4f64691e7461000055e09839fb10}"]],["addRenderer",["instance:${767e2df7-072c-4082-a002-4f64691e7461000055e0983c3f90}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055e098306160}"]],["addViewProp",["instance:${767e2df7-072c-4082-a002-4f64691e7461000055e097f57f60}"]]],"dependencies":[{"id":"000055e098306160","parent":"767e2df7-072c-4082-a002-4f64691e7461000055e0985ed060","properties":{"clippingRange":[28.369623003252407,64.51276500590318],"focalPoint":[4.5,4.5,4.5],"position":[30 ...
