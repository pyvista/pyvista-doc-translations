# %%
import pyvista as pv
pv.set_jupyter_backend('panel')
pv.set_plot_theme('document')

# %%
import numpy as np
import pyvista as pv

nodes = np.random.rand(100, 3)
mesh = pv.PolyData(nodes)
mesh.plot(point_size=10)
# Out:
# <div id='1003'>
#
#
#
#
#
#   <div class="bk-root" id="7f6d698d-c163-4e21-a964-300f83434547" data-root-id="1003"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ddd0469a-936a-4c62-b722-f5d759b4cb7e":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"reload":false},"id":"1005","type":"panel.models.location.Location"},{"attributes":{"arrays":{"0ceedb4bc22e44d634573a17517865d5":"...","2ebda7d3c6c3627ba233a85b7027cd58":"...","e361de470385ca350ab5283b6e899ab5":"..."},"axes":{"id":"1002"},"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d0d22770}"]],["addRenderer",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d0d319f0}"]],["addRenderer",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d0d21700}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005563d109b7a0}"]],["addViewProp",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d11115d0}"]]],"dependencies":[{"id":"00005563d109b7a0","parent":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d0d22770","properties":{"clippingRange":[1.55805032939984,5.456472999568809],"focalPoint":[0.4890159719773,0.49739291342130887,0.49401807000601566],"position":[2.3829754802472434,2.391352421691252,2.387977578275959],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d110e8d0}"]],["setProperty",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563cf8964b0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d110e8d0-dataset-0}",0]],["setLookupTable",["instance:${7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d0aa9b60}"]]],"dependencies":[{"id":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d110e8d0-dataset-0","parent":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d110e8d0","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"0ceedb4bc22e44d634573a17517865d5","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.9772758647399009,"min":0.0007560792146991124},{"component":null,"max":0.9892861776023294,"min":0.00549964924028834},{"component":null,"max":0.984436475018064,"min":0.0035996649939673553},{"component":null,"max":1.3838103093083767,"min":0.3140699899782275}],"size":300,"vtkClass":"vtkPoints"},"verts":{"dataType":"Uint32Array","hash":"e361de470385ca350ab5283b6e899ab5","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":99.0,"min":0.0}],"size":200,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d0aa9b60","parent":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d110e8d0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d110e8d0","parent":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d11115d0","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563cf8964b0","parent":"7fd41d72-1117-4daa-b7f9-b8dba795b0e300005563d11115d0","properties":{"ambient":0.0,"ambie ...
#     var render

# %%
from pyvista import examples

mesh = examples.load_hexbeam()
bcpos = [(6.20, 3.00, 7.50),
         (0.16, 0.13, 2.65),
         (-0.28, 0.94, -0.21)]

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
       point_size=10, render_points_as_spheres=True)
pl.camera_position = bcpos
pl.show()
# Out:
# <div id='1007'>
#
#
#
#
#
#   <div class="bk-root" id="dfa0ac8f-c2a5-4ebc-bfcb-70fa4480b171" data-root-id="1007"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"befd7b41-ef2b-4938-9d18-8d278ac322db":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"..."},"axes":{"id":"1006"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d20d0f10}"]],["addRenderer",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d1a049d0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005563d105bd20}"]],["addViewProp",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d19d5110}"]],["addViewProp",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d1bc7100}"]]],"dependencies":[{"id":"00005563d105bd20","parent":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d20d0f10","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d2067520}"]],["setProperty",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d20c0040}"]]],"dependencies":[{"calls":[["setInputData",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d2067520-dataset-0}",0]],["setLookupTable",["instance:${71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d1fa83c0}"]]],"dependencies":[{"id":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d2067520-dataset-0","parent":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d2067520","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d1fa83c0","parent":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d2067520","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d2067520","parent":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d19d5110","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d20c0040","parent":"71b1a2b1-f1cf-4a28-affd-bb79475e6e0c00005563d19d5110","properties":{"ambient":0.0,"ambientColor":[1.0,1.0,1.0],"backfaceCulling":0,"color":[1.0,1.0,1.0],"diffuse":1.0,"diffuseColor":[1.0,1.0,1.0],"edgeColor":[0.0,0.0,0.0],"edgeVisibility":1,"frontfaceCulling":0,"interpolation":0,"lighting":1,"lineWidth" ...

# %%
mesh = examples.download_bunny_coarse()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)
pl.camera_position = [(0.02, 0.30, 0.73),
                      (0.02, 0.03, -0.022),
                      (-0.03, 0.94, -0.34)]
pl.show()
# Out:
# <div id='1010'>
#
#
#
#
#
#   <div class="bk-root" id="802079d5-5ff5-4af5-9eeb-30fd2a8a6521" data-root-id="1010"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"9cfddcb5-78a0-4f54-a9de-1e0659d9f365":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"09274232a877f0c3c872ae7ea3573599":"...","233c95f9c627ae8343c4314291d001d7":"...","2ebda7d3c6c3627ba233a85b7027cd58":"...","364c82e904258502159946249464beb2":"...","bbd1e662f41e7ea2534dbeb97e952dff":"...","f126fd8aa224af8062956f0c00bc2c0c":"..."},"axes":{"id":"1009"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d2790740}"]],["addRenderer",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d20d0a40}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005563d27a8af0}"]],["addViewProp",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d26c17d0}"]],["addViewProp",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d26eaf00}"]]],"dependencies":[{"id":"00005563d27a8af0","parent":"80eba138-0ecd-448f-ba69-4d523e2a37a400005563d2790740","properties":{"clippingRange":[0.46024900135143143,1.2251304034277937],"focalPoint":[0.02,0.03,-0.022],"position":[0.02,0.3,0.73],"viewUp":[-0.02999850011249063,0.9399530035247063,-0.33998300127489384]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d27cbab0}"]],["setProperty",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d26c2d00}"]]],"dependencies":[{"calls":[["setInputData",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d27cbab0-dataset-0}",0]],["setLookupTable",["instance:${80eba138-0ecd-448f-ba69-4d523e2a37a400005563d2688db0}"]]],"dependencies":[{"id":"80eba138-0ecd-448f-ba69-4d523e2a37a400005563d27cbab0-dataset-0","parent":"80eba138-0ecd-448f-ba69-4d523e2a37a400005563d27cbab0","properties":{"fields":[{"dataType":"Float32Array","hash":"f126fd8aa224af8062956f0c00bc2c0c","location":"pointData","name":"Normals","numberOfComponents":3,"ranges":[{"component":null,"max":0.9976677298545837,"min":-0.9997695088386536},{"component":null,"max":0.9959895014762878,"min":-0.9998428821563721},{"component":null,"max":0.9974686503410339,"min":-0.998054563999176},{"component":null,"max":1.0000000408603298,"min":0.9999999604990634}],"registration":"setNormals","size":2616,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float32Array","hash":"364c82e904258502159946249464beb2","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.18016336858272552,"min":-0.13155962526798248},{"component":null,"max":0.18769524991512299,"min":-0.12048563361167908},{"component":null,"max":0.09850578755140305,"min":-0.14300920069217682},{"component":null,"max":0.23461699358757118,"min":0.0639391221071615}],"size":2616,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"233c95f9c627ae8343c4314291d001d7","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":871.0,"min":0.0}],"size":4000,"vtkClass":"vtkCellArray"},"verts":{"dataType":"Uint32Array","hash":"bbd1e662f41e7ea2534dbeb97e952dff","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":501.0,"min":0.0}],"size":1004,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"80eba138-0ecd-448f-ba69-4d523e2a37a400005563d2688db0","parent":"80eba138-0ecd-448f-ba69-4d523e2a37a400005563d27cbab0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"u ...

# %%
mesh = examples.load_hexbeam()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)

pl.add_mesh(mesh.extract_cells(mesh.n_cells-1),
            color='pink', edge_color='blue',
            line_width=5, show_edges=True)

pl.camera_position = [(6.20, 3.00, 7.50),
                      (0.16, 0.13, 2.65),
                      (-0.28, 0.94, -0.21)]
pl.show()
# Out:
# <div id='1013'>
#
#
#
#
#
#   <div class="bk-root" id="b29f801f-7602-4805-96b2-cdfa574d0635" data-root-id="1013"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f6fefecb-e5f5-4438-9931-0063f374410e":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{},"id":"1012","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"...","8a8291eb26fea509eef318c50eb0fdad":"","a990b5ac895ff54373e8552a7fadab2e":""},"axes":{"id":"1012"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2cb0f70}"]],["addRenderer",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d264eca0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005563d2e205f0}"]],["addViewProp",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2d70d10}"]],["addViewProp",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2c62310}"]],["addViewProp",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2d50f30}"]]],"dependencies":[{"id":"00005563d2e205f0","parent":"3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2cb0f70","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2c68640}"]],["setProperty",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2dcbab0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2c68640-dataset-0}",0]],["setLookupTable",["instance:${3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d26cabe0}"]]],"dependencies":[{"id":"3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2c68640-dataset-0","parent":"3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2c68640","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d26cabe0","parent":"3d841a5d-e43b-4eb8-b8a0-655f5481ab4e00005563d2c68640","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1}," ...

# %%
mesh.point_arrays['my point values'] = np.arange(mesh.n_points)

mesh.plot(scalars='my point values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1017'>
#
#
#
#
#
#   <div class="bk-root" id="66ba3986-3e78-4063-9e6b-214e87150a25" data-root-id="1017"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"26ae7f45-6839-4210-8671-c95131ca857b":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ce52d598102e2756143cf4f27a0b5911":"...","e2ddbba971096529c0fc99f7c8331f6b":"..."},"axes":{"id":"1016"},"color_mappers":[{"id":"1015"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d2e2c740}"]],["addRenderer",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3252a50}"]],["addRenderer",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d324a6b0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005563d2d68210}"]],["addViewProp",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d347c1f0}"]]],"dependencies":[{"id":"00005563d2d68210","parent":"e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d2e2c740","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3479aa0}"]],["setProperty",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d347cb70}"]]],"dependencies":[{"calls":[["setInputData",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3479aa0-dataset-0}",0]],["setLookupTable",["instance:${e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3445780}"]]],"dependencies":[{"id":"e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3479aa0-dataset-0","parent":"e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3479aa0","properties":{"fields":[{"dataType":"Int32Array","hash":"e2ddbba971096529c0fc99f7c8331f6b","location":"pointData","name":"my point values","numberOfComponents":1,"ranges":[{"component":null,"max":98.0,"min":0.0}],"registration":"setScalars","size":99,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3445780","parent":"e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3479aa0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[0.0,98.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,98.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d3479aa0","parent":"e05b8ca4-0ac1-46d6-b6ad-31f828acb40100005563d347c1f0","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":1,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":1,"scalarRange":[0.0,98.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"e05b8ca ...

# %%
mesh.cell_arrays['my cell values'] = np.arange(mesh.n_cells)
mesh.plot(scalars='my cell values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1021'>
#
#
#
#
#
#   <div class="bk-root" id="a478eb53-daf2-4af9-9d24-8a87f965adea" data-root-id="1021"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"81c32749-89c1-4b2a-976c-9022b08b4643":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{},"id":"1020","type":"panel.models.vtk.VTKAxes"},{"attributes":{"high":39.0,"low":0.0,"name":"my cell values","palette":["#440154","#440255","#440357","#450558","#45065a","#45085b","#46095c","#460b5e","#460c5f","#460e61","#470f62","#471163","#471265","#471466","#471567","#471669","#47186a","#48196b","#481a6c","#481c6e","#481d6f","#481e70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472a79","#472b7a","#472c7b","#462d7c","#462f7c","#46307d","#46317e","#45327f","#45347f","#453580","#453681","#443781","#443982","#433a83","#433b83","#433c84","#423d84","#423e85","#424085","#414186","#414286","#404387","#404487","#3f4587","#3f4788","#3e4888","#3e4989","#3d4a89","#3d4b89","#3d4c89","#3c4d8a","#3c4e8a","#3b508a","#3b518a","#3a528b","#3a538b","#39548b","#39558b","#38568b","#38578c","#37588c","#37598c","#365a8c","#365b8c","#355c8c","#355d8c","#345e8d","#345f8d","#33608d","#33618d","#32628d","#32638d","#31648d","#31658d","#31668d","#30678d","#30688d","#2f698d","#2f6a8d","#2e6b8e","#2e6c8e","#2e6d8e","#2d6e8e","#2d6f8e","#2c708e","#2c718e","#2c728e","#2b738e","#2b748e","#2a758e","#2a768e","#2a778e","#29788e","#29798e","#287a8e","#287a8e","#287b8e","#277c8e","#277d8e","#277e8e","#267f8e","#26808e","#26818e","#25828e","#25838d","#24848d","#24858d","#24868d","#23878d","#23888d","#23898d","#22898d","#228a8d","#228b8d","#218c8d","#218d8c","#218e8c","#208f8c","#20908c","#20918c","#1f928c","#1f938b","#1f948b","#1f958b","#1f968b","#1e978a","#1e988a","#1e998a","#1e998a","#1e9a89","#1e9b89","#1e9c89","#1e9d88","#1e9e88","#1e9f88","#1ea087","#1fa187","#1fa286","#1fa386","#20a485","#20a585","#21a685","#21a784","#22a784","#23a883","#23a982","#24aa82","#25ab81","#26ac81","#27ad80","#28ae7f","#29af7f","#2ab07e","#2bb17d","#2cb17d","#2eb27c","#2fb37b","#30b47a","#32b57a","#33b679","#35b778","#36b877","#38b976","#39b976","#3bba75","#3dbb74","#3ebc73","#40bd72","#42be71","#44be70","#45bf6f","#47c06e","#49c16d","#4bc26c","#4dc26b","#4fc369","#51c468","#53c567","#55c666","#57c665","#59c764","#5bc862","#5ec961","#60c960","#62ca5f","#64cb5d","#67cc5c","#69cc5b","#6bcd59","#6dce58","#70ce56","#72cf55","#74d054","#77d052","#79d151","#7cd24f","#7ed24e","#81d34c","#83d34b","#86d449","#88d547","#8bd546","#8dd644","#90d643","#92d741","#95d73f","#97d83e","#9ad83c","#9dd93a","#9fd938","#a2da37","#a5da35","#a7db33","#aadb32","#addc30","#afdc2e","#b2dd2c","#b5dd2b","#b7dd29","#bade27","#bdde26","#bfdf24","#c2df22","#c5df21","#c7e01f","#cae01e","#cde01d","#cfe11c","#d2e11b","#d4e11a","#d7e219","#dae218","#dce218","#dfe318","#e1e318","#e4e318","#e7e419","#e9e419","#ece41a","#eee51b","#f1e51c","#f3e51e","#f6e61f","#f8e621","#fae622","#fde724"]},"id":"1019","type":"LinearColorMapper"},{"attributes":{"client_comm_id":"0a3adaa9bc234ae0b07508bf056749d1","comm_id":"5f3712adc9d74ed5b7777fccc2a83e72","plot_id":"1021"},"id":"1022","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ac3fb6801e30e41f7b521cd44e0bea96":"","ce52d598102e2756143cf4f27a0b5911":"..."},"axes":{"id":"1020"},"color_mappers":[{"id":"1019"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${ebd086a6-7c3a-483a-9a2a-61ce700db22100005563d436c0b0}"]],["addRenderer",["instance:${ebd086a6-7c3a-483a-9a2a-61ce700db22100005563d41eac60}"]],["addRenderer",["instance:${ebd086a6-7c3a-483a-9a2a-61ce700db22100005563d4394530}"]]],"dependenci ...

# %%
mesh = examples.load_uniform()

pl = pv.Plotter(shape=(1,2))
pl.add_mesh(mesh, scalars='Spatial Point Data', show_edges=True)
pl.subplot(0,1)
pl.add_mesh(mesh, scalars='Spatial Cell Data', show_edges=True)
pl.show()
# Out:
# <div id='1025'>
#
#
#
#
#
#   <div class="bk-root" id="fcebad70-d301-4e88-9227-049d18ea0af5" data-root-id="1025"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"4856d6d3-30cb-46ed-82b9-23b0114b032d":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"82e430eab61792abaf6b93b3e7efbd26":"...","ce52d598102e2756143cf4f27a0b5911":"...","e29e0c63339d8d1d879b645e2c536af4":"...","ef0b202855df439aff207db187b28d7f":"...","f26b7ce42162ae450c6c0266500ad97e":"..."},"axes":{"id":"1024"},"color_mappers":[{"id":"1023"}],"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4b4f5d0}"]],["addRenderer",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d25529c0}"]],["addRenderer",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4ab6c70}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005563d4b8f410}"]],["addViewProp",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4953ed0}"]]],"dependencies":[{"id":"00005563d4b8f410","parent":"76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4b4f5d0","properties":{"clippingRange":[28.369623003252407,64.51276500590318],"focalPoint":[4.5,4.5,4.5],"position":[30.090110583571697,30.090110583571697,30.090110583571697],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bd98f0}"]],["setProperty",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bd8cf0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bd98f0-dataset-0}",0]],["setLookupTable",["instance:${76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bc3320}"]]],"dependencies":[{"id":"76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bd98f0-dataset-0","parent":"76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bd98f0","properties":{"fields":[{"dataType":"Float64Array","hash":"ef0b202855df439aff207db187b28d7f","location":"pointData","name":"Spatial Point Data","numberOfComponents":1,"ranges":[{"component":null,"max":729.0,"min":0.0}],"registration":"setScalars","size":488,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float32Array","hash":"e29e0c63339d8d1d879b645e2c536af4","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":9.0,"min":0.0},{"component":null,"max":9.0,"min":0.0},{"component":null,"max":9.0,"min":0.0},{"component":null,"max":15.588457268119896,"min":0.0}],"size":1464,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"f26b7ce42162ae450c6c0266500ad97e","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":487.0,"min":0.0}],"size":2430,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bc3320","parent":"76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bd98f0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[0.0,729.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,729.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4bd98f0","parent":"76fcf540-fe4e-4b4f-a424-425b4b1a54b200005563d4953ed0","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":1,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":1,"scalarRange":[0.0,729.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSe ...
