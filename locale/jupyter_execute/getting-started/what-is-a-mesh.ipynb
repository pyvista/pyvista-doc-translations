# %%
import pyvista as pv
pv.set_jupyter_backend('panel')
pv.set_plot_theme('document')

# %%
import numpy as np
import pyvista as pv

nodes = np.random.rand(100, 3)
mesh = pv.PolyData(nodes)
mesh.plot(point_size=10)
# Out:
# <div id='1003'>
#
#
#
#
#
#   <div class="bk-root" id="d9645164-404c-4064-99e9-27cd9d70bace" data-root-id="1003"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f463ae97-9fdd-421b-86ea-00b7f274bfef":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{},"id":"1002","type":"panel.models.vtk.VTKAxes"},{"attributes":{"client_comm_id":"8caa926605a543c3996b274b168bafb5","comm_id":"b9159ac8df8042489934cd68e7ee7517","plot_id":"1003"},"id":"1004","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","e361de470385ca350ab5283b6e899ab5":"...","ec24ed57c204b8bcb7e04aa2b886f3b4":"..."},"axes":{"id":"1002"},"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c511d970}"]],["addRenderer",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c511e420}"]],["addRenderer",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c512d6a0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005651c539a360}"]],["addViewProp",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550ca10}"]]],"dependencies":[{"id":"00005651c539a360","parent":"f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c511d970","properties":{"clippingRange":[1.560702281135595,5.464885005898831],"focalPoint":[0.4981495165039679,0.5085989893382634,0.5029166772353193],"position":[2.3951092024803575,2.405558675314653,2.3998763632117095],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550a190}"]],["setProperty",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c3c944b0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550a190-dataset-0}",0]],["setLookupTable",["instance:${f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c4d51320}"]]],"dependencies":[{"id":"f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550a190-dataset-0","parent":"f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550a190","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"ec24ed57c204b8bcb7e04aa2b886f3b4","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.9962268006397156,"min":7.223236822018198e-05},{"component":null,"max":0.9893403748946623,"min":0.027857603781864637},{"component":null,"max":0.9968390230880879,"min":0.00899433138255068},{"component":null,"max":1.6015005938196865,"min":0.10490841450071035}],"size":300,"vtkClass":"vtkPoints"},"verts":{"dataType":"Uint32Array","hash":"e361de470385ca350ab5283b6e899ab5","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":99.0,"min":0.0}],"size":200,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c4d51320","parent":"f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550a190","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550a190","parent":"f82f3ec6-f8f5-4c4c-babd-5a29e6bf743400005651c550ca10","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkD ...
#     var re

# %%
from pyvista import examples

mesh = examples.load_hexbeam()
bcpos = [(6.20, 3.00, 7.50),
         (0.16, 0.13, 2.65),
         (-0.28, 0.94, -0.21)]

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
       point_size=10, render_points_as_spheres=True)
pl.camera_position = bcpos
pl.show()
# Out:
# <div id='1007'>
#
#
#
#
#
#   <div class="bk-root" id="ae51a0ff-859f-483a-86b9-7fbfc4526723" data-root-id="1007"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f17b7e84-462c-44b4-abcc-94a1b7db74b2":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"client_comm_id":"4bdc05fda45744c595ef3dd5d27aa886","comm_id":"fe6464a41a81447490d21f3a485423eb","plot_id":"1007"},"id":"1008","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"..."},"axes":{"id":"1006"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c5f2db50}"]],["addRenderer",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c583b8b0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005651c5490a00}"]],["addViewProp",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c5df3a20}"]],["addViewProp",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c5e51e90}"]]],"dependencies":[{"id":"00005651c5490a00","parent":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c5f2db50","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6466e20}"]],["setProperty",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c64b87a0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6466e20-dataset-0}",0]],["setLookupTable",["instance:${752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6510910}"]]],"dependencies":[{"id":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6466e20-dataset-0","parent":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6466e20","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6510910","parent":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6466e20","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c6466e20","parent":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c5df3a20","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c64b87a0","parent":"752d4a79-8bcc-416d-9e4a-af3182f4388800005651c5df3a20","properties":{"ambient":0.0,"ambientColor":[1.0,1.0,1.0],"ba ...

# %%
mesh = examples.download_bunny_coarse()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)
pl.camera_position = [(0.02, 0.30, 0.73),
                      (0.02, 0.03, -0.022),
                      (-0.03, 0.94, -0.34)]
pl.show()
# Out:
# <div id='1010'>
#
#
#
#
#
#   <div class="bk-root" id="319952b2-dd47-4778-9be2-47c5e0f78776" data-root-id="1010"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"3ef01b19-8005-4ed0-851b-4b71490900f8":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"client_comm_id":"e7e351aebf9e4848b390a22b2ac2fe5e","comm_id":"b7b3ad2c00434179a51344e49d096333","plot_id":"1010"},"id":"1011","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1009","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"09274232a877f0c3c872ae7ea3573599":"...","233c95f9c627ae8343c4314291d001d7":"...","2ebda7d3c6c3627ba233a85b7027cd58":"...","364c82e904258502159946249464beb2":"...","bbd1e662f41e7ea2534dbeb97e952dff":"...","f126fd8aa224af8062956f0c00bc2c0c":"..."},"axes":{"id":"1009"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c6baf1e0}"]],["addRenderer",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c64b81b0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005651c6ba0770}"]],["addViewProp",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c69d28b0}"]],["addViewProp",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c69bcc70}"]]],"dependencies":[{"id":"00005651c6ba0770","parent":"7b4c5597-ce60-49b2-b320-63ba6181101000005651c6baf1e0","properties":{"clippingRange":[0.46024900135143143,1.2251304034277937],"focalPoint":[0.02,0.03,-0.022],"position":[0.02,0.3,0.73],"viewUp":[-0.02999850011249063,0.9399530035247063,-0.33998300127489384]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c6951860}"]],["setProperty",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c69a02e0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c6951860-dataset-0}",0]],["setLookupTable",["instance:${7b4c5597-ce60-49b2-b320-63ba6181101000005651c6a32c20}"]]],"dependencies":[{"id":"7b4c5597-ce60-49b2-b320-63ba6181101000005651c6951860-dataset-0","parent":"7b4c5597-ce60-49b2-b320-63ba6181101000005651c6951860","properties":{"fields":[{"dataType":"Float32Array","hash":"f126fd8aa224af8062956f0c00bc2c0c","location":"pointData","name":"Normals","numberOfComponents":3,"ranges":[{"component":null,"max":0.9976677298545837,"min":-0.9997695088386536},{"component":null,"max":0.9959895014762878,"min":-0.9998428821563721},{"component":null,"max":0.9974686503410339,"min":-0.998054563999176},{"component":null,"max":1.0000000408603298,"min":0.9999999604990634}],"registration":"setNormals","size":2616,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float32Array","hash":"364c82e904258502159946249464beb2","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.18016336858272552,"min":-0.13155962526798248},{"component":null,"max":0.18769524991512299,"min":-0.12048563361167908},{"component":null,"max":0.09850578755140305,"min":-0.14300920069217682},{"component":null,"max":0.23461699358757118,"min":0.0639391221071615}],"size":2616,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"233c95f9c627ae8343c4314291d001d7","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":871.0,"min":0.0}],"size":4000,"vtkClass":"vtkCellArray"},"verts":{"dataType":"Uint32Array","hash":"bbd1e662f41e7ea2534dbeb97e952dff","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":501.0,"min":0.0}],"size":1004,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"7b4c5597-ce60-49b2-b320-63ba6181101000005651c6a32c20","parent":"7b4c5597-ce60-49b2-b320-63ba6181101000005651c6951860","prope ...

# %%
mesh = examples.load_hexbeam()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)

pl.add_mesh(mesh.extract_cells(mesh.n_cells-1),
            color='pink', edge_color='blue',
            line_width=5, show_edges=True)

pl.camera_position = [(6.20, 3.00, 7.50),
                      (0.16, 0.13, 2.65),
                      (-0.28, 0.94, -0.21)]
pl.show()
# Out:
# <div id='1013'>
#
#
#
#
#
#   <div class="bk-root" id="2516074b-c40e-4341-8bab-88488cbc46a0" data-root-id="1013"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"020724b6-6779-4b23-a5a8-63e5df050862":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{},"id":"1012","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"...","8a8291eb26fea509eef318c50eb0fdad":"","a990b5ac895ff54373e8552a7fadab2e":""},"axes":{"id":"1012"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c7094fc0}"]],["addRenderer",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c7028e30}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005651c721b380}"]],["addViewProp",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c6bffcd0}"]],["addViewProp",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c705a6f0}"]],["addViewProp",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c63cd900}"]]],"dependencies":[{"id":"00005651c721b380","parent":"9add338d-4483-4c15-9067-921ecb5fb5f000005651c7094fc0","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c6ffcc40}"]],["setProperty",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c708c270}"]]],"dependencies":[{"calls":[["setInputData",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c6ffcc40-dataset-0}",0]],["setLookupTable",["instance:${9add338d-4483-4c15-9067-921ecb5fb5f000005651c71a3b40}"]]],"dependencies":[{"id":"9add338d-4483-4c15-9067-921ecb5fb5f000005651c6ffcc40-dataset-0","parent":"9add338d-4483-4c15-9067-921ecb5fb5f000005651c6ffcc40","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"9add338d-4483-4c15-9067-921ecb5fb5f000005651c71a3b40","parent":"9add338d-4483-4c15-9067-921ecb5fb5f000005651c6ffcc40","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1}," ...

# %%
mesh.point_arrays['my point values'] = np.arange(mesh.n_points)

mesh.plot(scalars='my point values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1017'>
#
#
#
#
#
#   <div class="bk-root" id="422c1f33-521b-4e50-ad13-c7f0936732da" data-root-id="1017"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"5f000058-d97b-469e-8661-e86123568b69":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"client_comm_id":"0143c8810f664b60bf62ebea376f99a6","comm_id":"aeb2839ded994c30958337380e204b01","plot_id":"1017"},"id":"1018","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ce52d598102e2756143cf4f27a0b5911":"...","e2ddbba971096529c0fc99f7c8331f6b":"..."},"axes":{"id":"1016"},"color_mappers":[{"id":"1015"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c76f5800}"]],["addRenderer",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c72099c0}"]],["addRenderer",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c772eee0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005651c3be6290}"]],["addViewProp",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c78d12f0}"]]],"dependencies":[{"id":"00005651c3be6290","parent":"9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c76f5800","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c7881dc0}"]],["setProperty",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c78d1c70}"]]],"dependencies":[{"calls":[["setInputData",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c7881dc0-dataset-0}",0]],["setLookupTable",["instance:${9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c76cc870}"]]],"dependencies":[{"id":"9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c7881dc0-dataset-0","parent":"9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c7881dc0","properties":{"fields":[{"dataType":"Int32Array","hash":"e2ddbba971096529c0fc99f7c8331f6b","location":"pointData","name":"my point values","numberOfComponents":1,"ranges":[{"component":null,"max":98.0,"min":0.0}],"registration":"setScalars","size":99,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c76cc870","parent":"9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c7881dc0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[0.0,98.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,98.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c7881dc0","parent":"9fb8d6dc-67be-4f41-b7c4-c69c81f6b99c00005651c78d12f0","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":1,"interpolateScalarsBeforeM ...

# %%
mesh.cell_arrays['my cell values'] = np.arange(mesh.n_cells)
mesh.plot(scalars='my cell values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1021'>
#
#
#
#
#
#   <div class="bk-root" id="91bd4e61-7b93-4c14-bdbd-5974d9288d3e" data-root-id="1021"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"758e04dd-3155-42c7-9523-bd3b4a90d8f1":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ac3fb6801e30e41f7b521cd44e0bea96":"","ce52d598102e2756143cf4f27a0b5911":"..."},"axes":{"id":"1020"},"color_mappers":[{"id":"1019"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c81264a0}"]],["addRenderer",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c8002490}"]],["addRenderer",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c7c79680}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005651c88272c0}"]],["addViewProp",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c879dfb0}"]]],"dependencies":[{"id":"00005651c88272c0","parent":"38918c00-9493-49f9-a8ee-5f518985708d00005651c81264a0","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c879b7b0}"]],["setProperty",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c879e930}"]]],"dependencies":[{"calls":[["setInputData",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c879b7b0-dataset-0}",0]],["setLookupTable",["instance:${38918c00-9493-49f9-a8ee-5f518985708d00005651c8825470}"]]],"dependencies":[{"id":"38918c00-9493-49f9-a8ee-5f518985708d00005651c879b7b0-dataset-0","parent":"38918c00-9493-49f9-a8ee-5f518985708d00005651c879b7b0","properties":{"fields":[{"dataType":"Int32Array","hash":"ac3fb6801e30e41f7b521cd44e0bea96","location":"cellData","name":"my cell values","numberOfComponents":1,"ranges":[{"component":null,"max":39.0,"min":0.0}],"registration":"setScalars","size":88,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"38918c00-9493-49f9-a8ee-5f518985708d00005651c8825470","parent":"38918c00-9493-49f9-a8ee-5f518985708d00005651c879b7b0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[0.0,39.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,39.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"38918c00-9493-49f9-a8ee-5f518985708d00005651c879b7b0","parent":"38918c00-9493-49f9- ...

# %%
mesh = examples.load_uniform()

pl = pv.Plotter(shape=(1,2))
pl.add_mesh(mesh, scalars='Spatial Point Data', show_edges=True)
pl.subplot(0,1)
pl.add_mesh(mesh, scalars='Spatial Cell Data', show_edges=True)
pl.show()
# Out:
# <div id='1025'>
#
#
#
#
#
#   <div class="bk-root" id="ab16b582-9253-468a-a26e-8354b5c816be" data-root-id="1025"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"785c9100-9503-489c-8ed4-e209682fc895":{"defs":[{"extends":null,"module":null,"name":"DataModel","overrides":[],"properties":[]}],"roots":{"references":[{"attributes":{"client_comm_id":"b27f433a57674a38a51a465aeba8e744","comm_id":"213bf15adc4343f98f65e98586816817","plot_id":"1025"},"id":"1026","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1024","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"82e430eab61792abaf6b93b3e7efbd26":"...","ce52d598102e2756143cf4f27a0b5911":"...","e29e0c63339d8d1d879b645e2c536af4":"...","ef0b202855df439aff207db187b28d7f":"...","f26b7ce42162ae450c6c0266500ad97e":"..."},"axes":{"id":"1024"},"color_mappers":[{"id":"1023"}],"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c890a730}"]],["addRenderer",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c699d760}"]],["addRenderer",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c84cef90}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005651c8ff98f0}"]],["addViewProp",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8ee40e0}"]]],"dependencies":[{"id":"00005651c8ff98f0","parent":"4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c890a730","properties":{"clippingRange":[28.369623003252407,64.51276500590318],"focalPoint":[4.5,4.5,4.5],"position":[30.090110583571697,30.090110583571697,30.090110583571697],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8f133f0}"]],["setProperty",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8fa4080}"]]],"dependencies":[{"calls":[["setInputData",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8f133f0-dataset-0}",0]],["setLookupTable",["instance:${4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8ffc700}"]]],"dependencies":[{"id":"4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8f133f0-dataset-0","parent":"4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8f133f0","properties":{"fields":[{"dataType":"Float64Array","hash":"ef0b202855df439aff207db187b28d7f","location":"pointData","name":"Spatial Point Data","numberOfComponents":1,"ranges":[{"component":null,"max":729.0,"min":0.0}],"registration":"setScalars","size":488,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float32Array","hash":"e29e0c63339d8d1d879b645e2c536af4","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":9.0,"min":0.0},{"component":null,"max":9.0,"min":0.0},{"component":null,"max":9.0,"min":0.0},{"component":null,"max":15.588457268119896,"min":0.0}],"size":1464,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"f26b7ce42162ae450c6c0266500ad97e","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":487.0,"min":0.0}],"size":2430,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8ffc700","parent":"4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8f133f0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[0.0,729.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,729.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8f133f0","parent":"4e224120-d3c8-4d08-a6ad-b312fcabdd4d00005651c8ee40e0","properties ...
