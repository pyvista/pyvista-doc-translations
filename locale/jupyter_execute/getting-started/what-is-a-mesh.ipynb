# %%
import pyvista as pv
pv.set_jupyter_backend('panel')
pv.set_plot_theme('document')

# %%
import numpy as np
import pyvista as pv

nodes = np.random.rand(100, 3)
mesh = pv.PolyData(nodes)
mesh.plot(point_size=10)
# Out:
# <div id='1003'>
#
#
#
#
#
#   <div class="bk-root" id="87630e73-a456-4752-a9b8-c267eb3e5eb3" data-root-id="1003"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"32ba29f7-bc52-480d-a194-d461d4a6445d":{"defs":[],"roots":{"references":[{"attributes":{},"id":"1002","type":"panel.models.vtk.VTKAxes"},{"attributes":{"client_comm_id":"d26670fba7124047859500c493f1a96c","comm_id":"bd1f3de483424bd4b221365e502bf6f5","plot_id":"1003"},"id":"1004","type":"panel.models.comm_manager.CommManager"},{"attributes":{"reload":false},"id":"1005","type":"panel.models.location.Location"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","46c2d5cd28d1234aa963c9188dfba0db":"...","e361de470385ca350ab5283b6e899ab5":"..."},"axes":{"id":"1002"},"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696057860}"]],["addRenderer",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696047800}"]],["addRenderer",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558695dd54d0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055869631e890}"]],["addViewProp",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b00005586964440e0}"]]],"dependencies":[{"id":"000055869631e890","parent":"5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696057860","properties":{"clippingRange":[1.5599953296000422,5.462380613577274],"focalPoint":[0.4984501829895156,0.49735203327298966,0.4942394171491033],"position":[2.394543207894771,2.3934450581782447,2.3903324420543584],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696441860}"]],["setProperty",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558694bb74b0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696441860-dataset-0}",0]],["setLookupTable",["instance:${5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558695d62b50}"]]],"dependencies":[{"id":"5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696441860-dataset-0","parent":"5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696441860","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"46c2d5cd28d1234aa963c9188dfba0db","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.9952297511166911,"min":0.001670614862340103},{"component":null,"max":0.9925177920797136,"min":0.0021862744662657363},{"component":null,"max":0.9743569613363987,"min":0.01412187296180789},{"component":null,"max":1.5403710747673602,"min":0.06317102515898922}],"size":300,"vtkClass":"vtkPoints"},"verts":{"dataType":"Uint32Array","hash":"e361de470385ca350ab5283b6e899ab5","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":99.0,"min":0.0}],"size":200,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558695d62b50","parent":"5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696441860","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"5e9564dd-82c8-47b3-805c-ffbc20ed525b0000558696441860","parent":"5e9564dd-82c8-47b3-805c-ffbc20ed525b00005586964440e0","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type" ...
#     var render_items = [{"docid":"32ba29f7-bc52-480d-a194-d461d4a6445d","root_ids":["100

# %%
from pyvista import examples

mesh = examples.load_hexbeam()
bcpos = [(6.20, 3.00, 7.50),
         (0.16, 0.13, 2.65),
         (-0.28, 0.94, -0.21)]

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
       point_size=10, render_points_as_spheres=True)
pl.camera_position = bcpos
pl.show()
# Out:
# <div id='1007'>
#
#
#
#
#
#   <div class="bk-root" id="42e14af0-4127-46e1-b6e2-b6f614a11211" data-root-id="1007"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"91741ff9-828f-4775-a632-bdadfd26b81d":{"defs":[],"roots":{"references":[{"attributes":{"client_comm_id":"8a7574dd21cc430ead700c6cf51c3487","comm_id":"749fd83ed56c4fd99915d2d06c089c97","plot_id":"1007"},"id":"1008","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1006","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"..."},"axes":{"id":"1006"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc000055869679d1b0}"]],["addRenderer",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc0000558696d1fb90}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005586963c7c90}"]],["addViewProp",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc0000558696d04a40}"]],["addViewProp",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc0000558696d27dd0}"]]],"dependencies":[{"id":"00005586963c7c90","parent":"237783af-9a1d-4a4e-b823-cec55b4998cc000055869679d1b0","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc00005586973f34a0}"]],["setProperty",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc00005586973651f0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc00005586973f34a0-dataset-0}",0]],["setLookupTable",["instance:${237783af-9a1d-4a4e-b823-cec55b4998cc0000558697381ed0}"]]],"dependencies":[{"id":"237783af-9a1d-4a4e-b823-cec55b4998cc00005586973f34a0-dataset-0","parent":"237783af-9a1d-4a4e-b823-cec55b4998cc00005586973f34a0","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"237783af-9a1d-4a4e-b823-cec55b4998cc0000558697381ed0","parent":"237783af-9a1d-4a4e-b823-cec55b4998cc00005586973f34a0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"237783af-9a1d-4a4e-b823-cec55b4998cc00005586973f34a0","parent":"237783af-9a1d-4a4e-b823-cec55b4998cc0000558696d04a40","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":0,"interpolateScalarsBeforeMapping":1,"renderTime":0.0,"resolveCoincidentTopology":0,"scalarMode":5,"scalarRange":[0.0,1.0],"scalarVisibility":1,"useLookupTableScalarRange":0},"type":"vtkDataSetMapper"},{"id":"237783af-9a1d-4a4e-b823-cec55b4998cc00005586973651f0","parent":"237783af-9a1d-4a4e-b823-cec55b4998cc0000558696d04a40","properties":{"ambient":0.0,"ambientColor":[1.0,1.0,1.0],"backfaceCulling":0 ...

# %%
mesh = examples.download_bunny_coarse()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)
pl.camera_position = [(0.02, 0.30, 0.73),
                      (0.02, 0.03, -0.022),
                      (-0.03, 0.94, -0.34)]
pl.show()
# Out:
# <div id='1010'>
#
#
#
#
#
#   <div class="bk-root" id="ccbb1e8f-1d6a-4f58-b0ce-80eddee0ef1d" data-root-id="1010"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"fd3c04c5-27a0-40cd-a532-cbfd00da1151":{"defs":[],"roots":{"references":[{"attributes":{"arrays":{"09274232a877f0c3c872ae7ea3573599":"...","233c95f9c627ae8343c4314291d001d7":"...","2ebda7d3c6c3627ba233a85b7027cd58":"...","364c82e904258502159946249464beb2":"...","bbd1e662f41e7ea2534dbeb97e952dff":"...","f126fd8aa224af8062956f0c00bc2c0c":"..."},"axes":{"id":"1009"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${eec2c767-56e2-4b51-925d-20677397ad8600005586978899c0}"]],["addRenderer",["instance:${eec2c767-56e2-4b51-925d-20677397ad860000558696d41d10}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00005586979eeb20}"]],["addViewProp",["instance:${eec2c767-56e2-4b51-925d-20677397ad86000055869798fb20}"]],["addViewProp",["instance:${eec2c767-56e2-4b51-925d-20677397ad8600005586974ce910}"]]],"dependencies":[{"id":"00005586979eeb20","parent":"eec2c767-56e2-4b51-925d-20677397ad8600005586978899c0","properties":{"clippingRange":[0.46024900135143143,1.2251304034277937],"focalPoint":[0.02,0.03,-0.022],"position":[0.02,0.3,0.73],"viewUp":[-0.02999850011249063,0.9399530035247063,-0.33998300127489384]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${eec2c767-56e2-4b51-925d-20677397ad8600005586978a5ea0}"]],["setProperty",["instance:${eec2c767-56e2-4b51-925d-20677397ad860000558697a510b0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${eec2c767-56e2-4b51-925d-20677397ad8600005586978a5ea0-dataset-0}",0]],["setLookupTable",["instance:${eec2c767-56e2-4b51-925d-20677397ad860000558697a21ba0}"]]],"dependencies":[{"id":"eec2c767-56e2-4b51-925d-20677397ad8600005586978a5ea0-dataset-0","parent":"eec2c767-56e2-4b51-925d-20677397ad8600005586978a5ea0","properties":{"fields":[{"dataType":"Float32Array","hash":"f126fd8aa224af8062956f0c00bc2c0c","location":"pointData","name":"Normals","numberOfComponents":3,"ranges":[{"component":null,"max":0.9976677298545837,"min":-0.9997695088386536},{"component":null,"max":0.9959895014762878,"min":-0.9998428821563721},{"component":null,"max":0.9974686503410339,"min":-0.998054563999176},{"component":null,"max":1.0000000408603298,"min":0.9999999604990634}],"registration":"setNormals","size":2616,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float32Array","hash":"364c82e904258502159946249464beb2","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":0.18016336858272552,"min":-0.13155962526798248},{"component":null,"max":0.18769524991512299,"min":-0.12048563361167908},{"component":null,"max":0.09850578755140305,"min":-0.14300920069217682},{"component":null,"max":0.23461699358757118,"min":0.0639391221071615}],"size":2616,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"233c95f9c627ae8343c4314291d001d7","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":871.0,"min":0.0}],"size":4000,"vtkClass":"vtkCellArray"},"verts":{"dataType":"Uint32Array","hash":"bbd1e662f41e7ea2534dbeb97e952dff","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":501.0,"min":0.0}],"size":1004,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"eec2c767-56e2-4b51-925d-20677397ad860000558697a21ba0","parent":"eec2c767-56e2-4b51-925d-20677397ad8600005586978a5ea0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vectorComponent":0,"vectorMode" ...

# %%
mesh = examples.load_hexbeam()

pl = pv.Plotter()
pl.add_mesh(mesh, show_edges=True, color='white')
pl.add_mesh(pv.PolyData(mesh.points), color='red',
            point_size=10, render_points_as_spheres=True)

pl.add_mesh(mesh.extract_cells(mesh.n_cells-1),
            color='pink', edge_color='blue',
            line_width=5, show_edges=True)

pl.camera_position = [(6.20, 3.00, 7.50),
                      (0.16, 0.13, 2.65),
                      (-0.28, 0.94, -0.21)]
pl.show()
# Out:
# <div id='1013'>
#
#
#
#
#
#   <div class="bk-root" id="a2a1c2f7-269d-4608-a25a-000e74cc646b" data-root-id="1013"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"7951810c-dbbf-42c7-859c-e35e8e4558bd":{"defs":[],"roots":{"references":[{"attributes":{"client_comm_id":"930fef3202fd4e718357ada5d08d10a8","comm_id":"5e82815d628f449e933c6711dd5468bd","plot_id":"1013"},"id":"1014","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"2ebda7d3c6c3627ba233a85b7027cd58":"...","49cb4275d27552f7c25e442adf39ea0f":"...","871d59376d8da3b9b4fa25173ee80ac2":"...","879017733443cdbefd7e2ddf0ebe9117":"...","8a8291eb26fea509eef318c50eb0fdad":"","a990b5ac895ff54373e8552a7fadab2e":""},"axes":{"id":"1012"},"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf000055869799db90}"]],["addRenderer",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf00005586980c7830}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${0000558697f51cd0}"]],["addViewProp",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf0000558698057be0}"]],["addViewProp",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf0000558697f87d50}"]],["addViewProp",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf0000558697963cd0}"]]],"dependencies":[{"id":"0000558697f51cd0","parent":"2983353b-2475-4bef-bcac-66ad9d2793cf000055869799db90","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf0000558698165ad0}"]],["setProperty",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf0000558697f2b390}"]]],"dependencies":[{"calls":[["setInputData",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf0000558698165ad0-dataset-0}",0]],["setLookupTable",["instance:${2983353b-2475-4bef-bcac-66ad9d2793cf000055869805ce90}"]]],"dependencies":[{"id":"2983353b-2475-4bef-bcac-66ad9d2793cf0000558698165ad0-dataset-0","parent":"2983353b-2475-4bef-bcac-66ad9d2793cf0000558698165ad0","properties":{"fields":[],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"2ebda7d3c6c3627ba233a85b7027cd58","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":441.0963613542964,"min":360.62445840513925}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"2983353b-2475-4bef-bcac-66ad9d2793cf000055869805ce90","parent":"2983353b-2475-4bef-bcac-66ad9d2793cf0000558698165ad0","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.5,0.0,0.0,1.0],"numberOfColors":256,"range":[0.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,1.0],"vector ...

# %%
mesh.point_arrays['my point values'] = np.arange(mesh.n_points)

mesh.plot(scalars='my point values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1017'>
#
#
#
#
#
#   <div class="bk-root" id="ce245ede-cba3-4b90-bf4b-0906042bc8d2" data-root-id="1017"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"422bbe77-3344-4195-a5dc-224035afb1ea":{"defs":[],"roots":{"references":[{"attributes":{"high":98.0,"low":0.0,"name":"my point values","palette":["#440154","#440255","#440357","#450558","#45065a","#45085b","#46095c","#460b5e","#460c5f","#460e61","#470f62","#471163","#471265","#471466","#471567","#471669","#47186a","#48196b","#481a6c","#481c6e","#481d6f","#481e70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472a79","#472b7a","#472c7b","#462d7c","#462f7c","#46307d","#46317e","#45327f","#45347f","#453580","#453681","#443781","#443982","#433a83","#433b83","#433c84","#423d84","#423e85","#424085","#414186","#414286","#404387","#404487","#3f4587","#3f4788","#3e4888","#3e4989","#3d4a89","#3d4b89","#3d4c89","#3c4d8a","#3c4e8a","#3b508a","#3b518a","#3a528b","#3a538b","#39548b","#39558b","#38568b","#38578c","#37588c","#37598c","#365a8c","#365b8c","#355c8c","#355d8c","#345e8d","#345f8d","#33608d","#33618d","#32628d","#32638d","#31648d","#31658d","#31668d","#30678d","#30688d","#2f698d","#2f6a8d","#2e6b8e","#2e6c8e","#2e6d8e","#2d6e8e","#2d6f8e","#2c708e","#2c718e","#2c728e","#2b738e","#2b748e","#2a758e","#2a768e","#2a778e","#29788e","#29798e","#287a8e","#287a8e","#287b8e","#277c8e","#277d8e","#277e8e","#267f8e","#26808e","#26818e","#25828e","#25838d","#24848d","#24858d","#24868d","#23878d","#23888d","#23898d","#22898d","#228a8d","#228b8d","#218c8d","#218d8c","#218e8c","#208f8c","#20908c","#20918c","#1f928c","#1f938b","#1f948b","#1f958b","#1f968b","#1e978a","#1e988a","#1e998a","#1e998a","#1e9a89","#1e9b89","#1e9c89","#1e9d88","#1e9e88","#1e9f88","#1ea087","#1fa187","#1fa286","#1fa386","#20a485","#20a585","#21a685","#21a784","#22a784","#23a883","#23a982","#24aa82","#25ab81","#26ac81","#27ad80","#28ae7f","#29af7f","#2ab07e","#2bb17d","#2cb17d","#2eb27c","#2fb37b","#30b47a","#32b57a","#33b679","#35b778","#36b877","#38b976","#39b976","#3bba75","#3dbb74","#3ebc73","#40bd72","#42be71","#44be70","#45bf6f","#47c06e","#49c16d","#4bc26c","#4dc26b","#4fc369","#51c468","#53c567","#55c666","#57c665","#59c764","#5bc862","#5ec961","#60c960","#62ca5f","#64cb5d","#67cc5c","#69cc5b","#6bcd59","#6dce58","#70ce56","#72cf55","#74d054","#77d052","#79d151","#7cd24f","#7ed24e","#81d34c","#83d34b","#86d449","#88d547","#8bd546","#8dd644","#90d643","#92d741","#95d73f","#97d83e","#9ad83c","#9dd93a","#9fd938","#a2da37","#a5da35","#a7db33","#aadb32","#addc30","#afdc2e","#b2dd2c","#b5dd2b","#b7dd29","#bade27","#bdde26","#bfdf24","#c2df22","#c5df21","#c7e01f","#cae01e","#cde01d","#cfe11c","#d2e11b","#d4e11a","#d7e219","#dae218","#dce218","#dfe318","#e1e318","#e4e318","#e7e419","#e9e419","#ece41a","#eee51b","#f1e51c","#f3e51e","#f6e61f","#f8e621","#fae622","#fde724"]},"id":"1015","type":"LinearColorMapper"},{"attributes":{},"id":"1016","type":"panel.models.vtk.VTKAxes"},{"attributes":{"client_comm_id":"e0c08526bf714c8fb58c5222db3056a9","comm_id":"92d426aa59b54a91832c24a8e97adda4","plot_id":"1017"},"id":"1018","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ce52d598102e2756143cf4f27a0b5911":"...","e2ddbba971096529c0fc99f7c8331f6b":"..."},"axes":{"id":"1016"},"color_mappers":[{"id":"1015"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${2a1050b8-e449-4ce1-b9e2-724ab7cc73f100005586985f83f0}"]],["addRenderer",["instance:${2a1050b8-e449-4ce1-b9e2-724ab7cc73f100005586985a1730}"]],["addRenderer",["instance:${2a1050b8-e449-4ce1-b9e2-724ab7cc73f100005586986d5890}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055869818cfc0}"]],["addViewProp",["instance:${2a1050b8-e449-4ce1-b9e2-724ab7cc73f100005586987ae030}"]]],"dependencies":[{"id":"000055869818cfc0","parent":"2a1050b8-e449-4ce1-b9e2-724ab7cc73f100005586985f83f0","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.2791498 ...

# %%
mesh.cell_arrays['my cell values'] = np.arange(mesh.n_cells)
mesh.plot(scalars='my cell values', cpos=bcpos,
          show_edges=True)
# Out:
# <div id='1021'>
#
#
#
#
#
#   <div class="bk-root" id="3c7d485d-35e6-43b0-b2d8-74db34b8181d" data-root-id="1021"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"79ddbc56-77cd-4191-af40-3016f1e004c6":{"defs":[],"roots":{"references":[{"attributes":{"client_comm_id":"9dde4a817a6b438d9ad3b6c2bfef50c4","comm_id":"5b73416fbecc469684369ba1d8bad05a","plot_id":"1021"},"id":"1022","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"49cb4275d27552f7c25e442adf39ea0f":"...","879017733443cdbefd7e2ddf0ebe9117":"...","ac3fb6801e30e41f7b521cd44e0bea96":"","ce52d598102e2756143cf4f27a0b5911":"..."},"axes":{"id":"1020"},"color_mappers":[{"id":"1019"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b00005586995a52c0}"]],["addRenderer",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b0000558698b590a0}"]],["addRenderer",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b0000558698fa4bb0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055869971c080}"]],["addViewProp",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b00005586996db710}"]]],"dependencies":[{"id":"000055869971c080","parent":"726820c1-cc91-424c-84e1-7fee997dd92b00005586995a52c0","properties":{"clippingRange":[3.8979550091697854,13.119013824650803],"focalPoint":[0.16,0.13,2.65],"position":[6.2,3.0,7.5],"viewUp":[-0.279149887294591,0.9371460502032696,-0.2093624154709432]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b00005586996d8f10}"]],["setProperty",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b0000558699671390}"]]],"dependencies":[{"calls":[["setInputData",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b00005586996d8f10-dataset-0}",0]],["setLookupTable",["instance:${726820c1-cc91-424c-84e1-7fee997dd92b0000558699708760}"]]],"dependencies":[{"id":"726820c1-cc91-424c-84e1-7fee997dd92b00005586996d8f10-dataset-0","parent":"726820c1-cc91-424c-84e1-7fee997dd92b00005586996d8f10","properties":{"fields":[{"dataType":"Int32Array","hash":"ac3fb6801e30e41f7b521cd44e0bea96","location":"cellData","name":"my cell values","numberOfComponents":1,"ranges":[{"component":null,"max":39.0,"min":0.0}],"registration":"setScalars","size":88,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float64Array","hash":"879017733443cdbefd7e2ddf0ebe9117","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":0.0},{"component":null,"max":1.0,"min":0.0},{"component":null,"max":5.0,"min":0.0},{"component":null,"max":5.196152422706632,"min":0.0}],"size":297,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"49cb4275d27552f7c25e442adf39ea0f","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":89.0,"min":0.0}],"size":440,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"726820c1-cc91-424c-84e1-7fee997dd92b0000558699708760","parent":"726820c1-cc91-424c-84e1-7fee997dd92b00005586996d8f10","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[0.0,39.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[0.0,39.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type ...

# %%
mesh = examples.load_uniform()

pl = pv.Plotter(shape=(1,2))
pl.add_mesh(mesh, scalars='Spatial Point Data', show_edges=True)
pl.subplot(0,1)
pl.add_mesh(mesh, scalars='Spatial Cell Data', show_edges=True)
pl.show()
# Out:
# <div id='1025'>
#
#
#
#
#
#   <div class="bk-root" id="67391eaf-50f6-453e-8d8c-f2ff8214aa2b" data-root-id="1025"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"87fddcc7-af34-4c60-9a72-24fcfd473565":{"defs":[],"roots":{"references":[{"attributes":{"high":729.0,"low":0.0,"name":"Spatial Point Data","palette":["#440154","#440255","#440357","#450558","#45065a","#45085b","#46095c","#460b5e","#460c5f","#460e61","#470f62","#471163","#471265","#471466","#471567","#471669","#47186a","#48196b","#481a6c","#481c6e","#481d6f","#481e70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472a79","#472b7a","#472c7b","#462d7c","#462f7c","#46307d","#46317e","#45327f","#45347f","#453580","#453681","#443781","#443982","#433a83","#433b83","#433c84","#423d84","#423e85","#424085","#414186","#414286","#404387","#404487","#3f4587","#3f4788","#3e4888","#3e4989","#3d4a89","#3d4b89","#3d4c89","#3c4d8a","#3c4e8a","#3b508a","#3b518a","#3a528b","#3a538b","#39548b","#39558b","#38568b","#38578c","#37588c","#37598c","#365a8c","#365b8c","#355c8c","#355d8c","#345e8d","#345f8d","#33608d","#33618d","#32628d","#32638d","#31648d","#31658d","#31668d","#30678d","#30688d","#2f698d","#2f6a8d","#2e6b8e","#2e6c8e","#2e6d8e","#2d6e8e","#2d6f8e","#2c708e","#2c718e","#2c728e","#2b738e","#2b748e","#2a758e","#2a768e","#2a778e","#29788e","#29798e","#287a8e","#287a8e","#287b8e","#277c8e","#277d8e","#277e8e","#267f8e","#26808e","#26818e","#25828e","#25838d","#24848d","#24858d","#24868d","#23878d","#23888d","#23898d","#22898d","#228a8d","#228b8d","#218c8d","#218d8c","#218e8c","#208f8c","#20908c","#20918c","#1f928c","#1f938b","#1f948b","#1f958b","#1f968b","#1e978a","#1e988a","#1e998a","#1e998a","#1e9a89","#1e9b89","#1e9c89","#1e9d88","#1e9e88","#1e9f88","#1ea087","#1fa187","#1fa286","#1fa386","#20a485","#20a585","#21a685","#21a784","#22a784","#23a883","#23a982","#24aa82","#25ab81","#26ac81","#27ad80","#28ae7f","#29af7f","#2ab07e","#2bb17d","#2cb17d","#2eb27c","#2fb37b","#30b47a","#32b57a","#33b679","#35b778","#36b877","#38b976","#39b976","#3bba75","#3dbb74","#3ebc73","#40bd72","#42be71","#44be70","#45bf6f","#47c06e","#49c16d","#4bc26c","#4dc26b","#4fc369","#51c468","#53c567","#55c666","#57c665","#59c764","#5bc862","#5ec961","#60c960","#62ca5f","#64cb5d","#67cc5c","#69cc5b","#6bcd59","#6dce58","#70ce56","#72cf55","#74d054","#77d052","#79d151","#7cd24f","#7ed24e","#81d34c","#83d34b","#86d449","#88d547","#8bd546","#8dd644","#90d643","#92d741","#95d73f","#97d83e","#9ad83c","#9dd93a","#9fd938","#a2da37","#a5da35","#a7db33","#aadb32","#addc30","#afdc2e","#b2dd2c","#b5dd2b","#b7dd29","#bade27","#bdde26","#bfdf24","#c2df22","#c5df21","#c7e01f","#cae01e","#cde01d","#cfe11c","#d2e11b","#d4e11a","#d7e219","#dae218","#dce218","#dfe318","#e1e318","#e4e318","#e7e419","#e9e419","#ece41a","#eee51b","#f1e51c","#f3e51e","#f6e61f","#f8e621","#fae622","#fde724"]},"id":"1023","type":"LinearColorMapper"},{"attributes":{"client_comm_id":"2cecd6864c924e298c6ef6acfad1d287","comm_id":"edbc9fa52ee140ddb2439bedda80dcb1","plot_id":"1025"},"id":"1026","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1024","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"82e430eab61792abaf6b93b3e7efbd26":"...","ce52d598102e2756143cf4f27a0b5911":"...","e29e0c63339d8d1d879b645e2c536af4":"...","ef0b202855df439aff207db187b28d7f":"...","f26b7ce42162ae450c6c0266500ad97e":"..."},"axes":{"id":"1024"},"color_mappers":[{"id":"1023"}],"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${3305c185-a58d-4414-9288-4ed1da377b0700005586995da5e0}"]],["addRenderer",["instance:${3305c185-a58d-4414-9288-4ed1da377b070000558699e82140}"]],["addRenderer",["instance:${3305c185-a58d-4414-9288-4ed1da377b070000558699f28010}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${0000558699ed2570}"]],["addViewProp",["instance:${3305c185-a58d-4414-9288-4ed1da377b070000558699d42660}"]]],"dependencies":[{"id":"0000558699ed2570","parent":"3305c185-a58d-4414-9288-4ed1da377b0700005586995da5e0","properties":{"clippingRange":[28.369623003252407,64.51276500590318],"focalPoint":[4.5,4.5,4.5],"position":[30.090110583571697 ...
