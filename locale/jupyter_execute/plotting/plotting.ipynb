# %%
import pyvista as pv
sphere = pv.Sphere()
sphere.plot(jupyter_backend='static')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FA68C8191D0>

# %%
plotter = pv.Plotter(notebook=True)
plotter.add_mesh(sphere)
plotter.show(jupyter_backend='static')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FA68C8191D0>

# %%
plotter = pv.Plotter(notebook=True)
plotter.add_mesh(sphere)
plotter.show(jupyter_backend='ipygany')
# Out:
# Scene(background_color='#4c4c4c', camera={'position': [0.9632245055362663, 0.9632245055362663, 0.9632245055362…
